# %%
import pandas as pd
import nltk
import numpy as np
import pickle
import re
import gc

from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from gensim.models.keyedvectors import KeyedVectors

from keras.preprocessing.text import Tokenizer

import Utils.data_utils as data
# Out:
# Using TensorFlow backend.

# %%
#%time data_x, data_y = load_data('dataset/Raw/Train.tsv', [1, 3, 4], True, 1)
MAX_NB_WORDS = 30000
EMBEDDING_DIM = 200
MAX_SEQUENCE_LENGTH = 10000

path_train = 'dataset/Raw/Train.csv'
path_test = 'dataset/Raw/Test.csv'
path_w2v = 'W2V/wikipedia-pubmed-and-PMC-w2v.bin' # http://evexdb.org/pmresources/vec-space-models/

tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
dataset = data.Dataset()

# %%
#dataset.load_pickle(path_train, path_test, label_name='rating')
dataset.load_csv(path_train, path_test, label_name='rating', separator='\t', columns=[3,4])
dataset.parse_to_word_list(parse_col_name='review', alphanum_sep=True)
# model = KeyedVectors.load_word2vec_format(path_w2v, binary=True)

# %%
dataset.get_train_x()
# Out:
#                                                    review
# 0       "It has no side effect, I take it in combinati...
# 1       "My son is halfway through his fourth week of ...
# 2       "I used to take another oral contraceptive, wh...
# 3       "This is my first time using any form of birth...
# 4       "Suboxone has completely turned my life around...
# 5       "2nd day on 5mg started to work with rock hard...
# 6       "He pulled out, but he cummed a bit in me. I t...
# 7       "Abilify changed my life. There is hope. I was...
# 8       " I Ve had  nothing but problems with the Kepp...
# 9       "I had been on the pill for many years. When m...
# 10      "I have been on this medication almost two wee...
# 11      "I have taken anti-depressants for years, with...
# 12      "I had Crohn's with a resection 30 years ago a...
# 13      "Have a little bit of a lingering cough from a...
# 14      "Started Nexplanon 2 months ago because I have...
# 15      "I have been taking Saxenda since July 2016.  ...
# 16      "This drug worked very well for me and cleared...
# 17      "I've been taking amitriptyline since January ...
# 18      "I've been on every medicine under the sun (it...
# 19      "I have been on Tasigna for just over 3 years ...
# 20      "Spring of 2008 I was hospitalized with pnuemo...
# 21      "I have insomnia, it's horrible. My story begi...
# 22      "Nexplanon does its job. I can have worry free...
# 23      "I live in Western Australia and disturbed by ...
# 24      "Do not use the cream that comes with this. It...
# 25      "Was prescribed one dose over the course of on...
# 26      "I'm writing a second review on Vaniqa.  I sta...
# 27      "Hi all, My son who is 12 was diagnosed when h...
# 28      "Honestly, I have been taking ativan for 2 yea...
# 29      "At first I suffered through them. This includ...
# ...                                                   ...
# 161267  "Doc prescribed this medication to control my ...
# 161268  "I switched to Portia 12 days ago when I start...
# 161269  "When I first starting taking Lo Loestrin Fe, ...
# 161270  "I have been taking Cymbalta for 15 months now...
# 161271  "My experience: Painful insertion but I expect...
# 161272  "This really did help with my allergies and as...
# 161273  "I have had the Nexplanon since Dec. 27, 2016 ...
# 161274  "I need bi-lateral knee replacement but due to...
# 161275  "POISON....two days on this med & I thought I ...
# 161276  "About 4 years ago I started having early-morn...
# 161277  "I started taking this medication 10 years ago...
# 161278  "I just got diagnosed with type 2. My doctor p...
# 161279  "Used with my throat cancer and it helped numb...
# 161280  "Honestly , This works pretty well for me. It ...
# 161281  "Had taken Armour Thyroid for 20 years but sta...
# 161282  "I'm a 59 year old male who has experienced mo...
# 161283  "I was in a very bad place at the time I start...
# 161284  "Had panic attacks and social anxiety starting...
# 161285  "Used this a month ago for allergic conjunctiv...
# 161286  "This is the third med I've tried for anxiety ...
# 161287  "I was super against taking medication. I've s...
# 161288  "I have been off Prozac for about 4 weeks now....
# 161289  "Up to 800mg seems to work about once every 2n...
# 161290  "I have only been on Tekturna for 9 days. The ...
# 161291  "This would be my second month on Junel. I've ...
# 161292  "I wrote my first report in Mid-October of 201...
# 161293  "I was given this in IV before surgey. I immed...
# 161294  "Limited improvement after 4 months, developed...
# 161295  "I've been on thyroid medication 49 years, I s...
# 161296  "I've had chronic constipation all my adult li...
#
# [161297 rows x 1 columns]
